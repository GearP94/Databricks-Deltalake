# %%
# %sql
USE CATALOG hive_metastore

# %%
# %sql
CREATE TABLE employees (id INT, name STRING, salary DOUBLE)

# %%
# %sql
INSERT INTO employees VALUES (1, "Gama", 45000.7), (2, "Maria", 55009.4);

INSERT INTO employees VALUES (3, "Pedro", 65000.1), (4, "Jose", 75000.2);

INSERT INTO employees VALUES (5, "Ana", 85000.3), (6, "Carlos", 95000.4);

# %%
# %sql
select * from employees

# %%
# %sql
DESCRIBE DETAIL employees

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employees'

# %%
# %sql
UPDATE employees
SET salary = salary +100
WHERE name LIKE "A%"

# %%
# %sql
SELECT *FROM Employees

# %%
# %sql
DESCRIBE HISTORY employees

# %%
# %fs ls 'dbfs:/user/hive/warehouse/employees/_delta_log'

# %%
# %fs head 'dbfs:/user/hive/warehouse/employees/_delta_log/00000000000000000005.json'

# %%
# %sql
SELECT * FROM employees
  VERSION AS OF 3

# %%
# %sql
DELETE FROM employees

# %%
# %sql
restore Table employees to version as of 4

# %%
# %sql
select * from employees

# %%
# %sql
describe history employees
